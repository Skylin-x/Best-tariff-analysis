# %% [markdown]
# ## Содержание:
# * [Описание проекта](#10)
# * [Открытие файлов с данными и изучение общей информации](#1)
# * [Приведение типов данных и проверка на дубликаты](#2)
# * [Количество сделанных звонков и израсходованных минут разговора по месяцам](#3)
# * [Количество отправленных сообщений по месяцам](#4)
# * [Объем израсходованного интернет-трафика по месяцам](#5)
# * [Расчет помесячной выручки с каждого пользователя по месяцам](#6)
# * [Анализ полученных данных](#7)
# * [Проверка гипотез](#8)
# * [Выводы](#9)

# %% [markdown]
# <a id='10'></a>
# Описание проекта
# Компания — федеральный оператор сотовой связи предлагает клиентам два тарифных плана: «Смарт» и «Ультра».
# Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег.
# Необходимо провести предварительный анализ тарифов на небольшой выборке клиентов: 500 пользователей «Мегалайна».
# Данные: кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год. Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.
# Описание тарифов:
# Тариф «Смарт»
# Ежемесячная плата: 550 рублей
# Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
# Стоимость услуг сверх тарифного пакета:
# минута разговора: 3 рубля
# сообщение: 3 рубля
# 1 Гб интернет-трафика: 200 рублей
# Тариф «Ультра»
# Ежемесячная плата: 1950 рублей
# Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
# Стоимость услуг сверх тарифного пакета:
# минута разговора: 1 рубль
# сообщение: 1 рубль
# 1 Гб интернет-трафика: 150 рублей

# %% [markdown]
# <a id='1'></a>
# # 1. Открытие файлов с данными и изучение общей информации

# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
from scipy import stats as st

# %%
calls = pd.read_csv('calls.csv')
internet = pd.read_csv('internet.csv')
messages = pd.read_csv('messages.csv')
tariffs = pd.read_csv('tariffs.csv')
users = pd.read_csv('users.csv')

# %%
df = {'calls':calls,'internet':internet,'messages':messages,'tariffs':tariffs,'users':users}
for key,value in df.items():
    print(f'описание датасета {key}:')
    print('__________________________')
    display(value.head(5))
    display(value.info())
    display(value.describe())
# Out:
# описание датасета calls:
# __________________________
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB
# None
#             duration        user_id
# count  202607.000000  202607.000000
# mean        6.755887    1253.940619
# std         5.843365     144.722751
# min         0.000000    1000.000000
# 25%         1.300000    1126.000000
# 50%         6.000000    1260.000000
# 75%        10.700000    1379.000000
# max        38.000000    1499.000000
# описание датасета internet:
# __________________________
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB
# None
#           Unnamed: 0        mb_used        user_id
# count  149396.000000  149396.000000  149396.000000
# mean    74697.500000     370.192426    1252.099842
# std     43127.054745     278.300951     144.050823
# min         0.000000       0.000000    1000.000000
# 25%     37348.750000     138.187500    1130.000000
# 50%     74697.500000     348.015000    1251.000000
# 75%    112046.250000     559.552500    1380.000000
# max    149395.000000    1724.830000    1499.000000
# описание датасета messages:
# __________________________
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB
# None
#              user_id
# count  123036.000000
# mean     1256.989410
# std       143.523967
# min      1000.000000
# 25%      1134.000000
# 50%      1271.000000
# 75%      1381.000000
# max      1499.000000
# описание датасета tariffs:
# __________________________
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   rub_monthly_fee        2 non-null      int64
#  4   rub_per_gb             2 non-null      int64
#  5   rub_per_message        2 non-null      int64
#  6   rub_per_minute         2 non-null      int64
#  7   tariff_name            2 non-null      object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes
# None
#        messages_included  mb_per_month_included  minutes_included  \
# count           2.000000               2.000000          2.000000
# mean          525.000000           23040.000000       1750.000000
# std           671.751442           10861.160159       1767.766953
# min            50.000000           15360.000000        500.000000
# 25%           287.500000           19200.000000       1125.000000
# 50%           525.000000           23040.000000       1750.000000
# 75%           762.500000           26880.000000       2375.000000
# max          1000.000000           30720.000000       3000.000000
#
#        rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute
# count         2.000000    2.000000         2.000000        2.000000
# mean       1250.000000  175.000000         2.000000        2.000000
# std         989.949494   35.355339         1.414214        1.414214
# min         550.000000  150.000000         1.000000        1.000000
# 25%         900.000000  162.500000         1.500000        1.500000
# 50%        1250.000000  175.000000         2.000000        2.000000
# 75%        1600.000000  187.500000         2.500000        2.500000
# max        1950.000000  200.000000         3.000000        3.000000
# описание датасета users:
# __________________________
#    user_id  age churn_date         city first_name  last_name    reg_date  \
# 0     1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1     1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2     1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3     1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4     1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
# None
#            user_id        age
# count   500.000000  500.00000
# mean   1249.500000   46.58800
# std     144.481833   16.66763
# min    1000.000000   18.00000
# 25%    1124.750000   32.00000
# 50%    1249.500000   46.00000
# 75%    1374.250000   62.00000
# max    1499.000000   75.00000

# %% [markdown]
# <a id='2'></a>
# # 2. Приведение типов данных и проверка на дубликаты

# %%
calls['call_id'] = calls['id'].apply(lambda x: x[5:])
calls['call_month'] = calls['call_date'].apply(lambda x: (dt.strptime(x[:-3],'%Y-%m')))
calls = calls.astype({'call_date':np.datetime64,
                     'call_id':np.uint16,
                    'user_id':np.uint16})

internet['internet_id'] = internet['id'].apply(lambda x: x[5:])
internet['internet_month'] = internet['session_date'].apply(lambda x: (dt.strptime(x[:-3],'%Y-%m')))
internet = internet.astype({'session_date':np.datetime64,
                            'internet_id':np.uint16,
                           'user_id':np.uint16})

messages['message_id'] = messages['id'].apply(lambda x: x[5:])
messages['message_month'] = messages['message_date'].apply(lambda x: (dt.strptime(x[:-3],'%Y-%m')))
messages = messages.astype({'message_date':np.datetime64,
                            'message_id':np.uint16,
                           'user_id':np.uint16})

print('Уникальные названия тарифов в "tariffs"',tariffs['tariff_name'].unique())

users['reg_month'] = users['reg_date'].apply(lambda x: (dt.strptime(x[:-3],'%Y-%m')))
users = users.astype({'reg_date':np.datetime64,
                     'churn_date':np.datetime64,
                     'user_id':np.uint16,
                     'age':np.uint8})

print('Уникальные названия тарифов в "users"',users['tariff'].unique())
tariffs = tariffs.astype(
    {'messages_included':np.uint16,
     'mb_per_month_included':np.uint16,
     'minutes_included':np.uint16,
     'rub_monthly_fee':np.uint16,
     'rub_per_gb':np.uint16,
     'rub_per_message':np.uint16,
     'rub_per_minute':np.uint16
    
})
# Out:
# Уникальные названия тарифов в "tariffs" ['smart' 'ultra']
# Уникальные названия тарифов в "users" ['ultra' 'smart']

# %% [markdown]
# Нумерация в 'calls', 'internet , 'messages' представлена user_id + id. Решено с помощью удаления user_id и '_' из номера.

# %%
df = {'calls':calls,'internet':internet,'messages':messages,'tariffs':tariffs,'users':users}
for key,value in df.items():
    print(f'описание датасета {key}:')
    print('__________________________')
    display(value.head(5))
    display(value.info())
    display(value.describe())
# Out:
# описание датасета calls:
# __________________________
#        id  call_date  duration  user_id  call_id call_month
# 0  1000_0 2018-07-25      0.00     1000        0 2018-07-01
# 1  1000_1 2018-08-17      0.00     1000        1 2018-08-01
# 2  1000_2 2018-06-11      2.85     1000        2 2018-06-01
# 3  1000_3 2018-09-21     13.80     1000        3 2018-09-01
# 4  1000_4 2018-12-15      5.18     1000        4 2018-12-01
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          202607 non-null  object
#  1   call_date   202607 non-null  datetime64[ns]
#  2   duration    202607 non-null  float64
#  3   user_id     202607 non-null  uint16
#  4   call_id     202607 non-null  uint16
#  5   call_month  202607 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(1), uint16(2)
# memory usage: 7.0+ MB
# None
#             duration        user_id        call_id
# count  202607.000000  202607.000000  202607.000000
# mean        6.755887    1253.940619     308.577181
# std         5.843365     144.722751     259.948786
# min         0.000000    1000.000000       0.000000
# 25%         1.300000    1126.000000     108.000000
# 50%         6.000000    1260.000000     243.000000
# 75%        10.700000    1379.000000     446.000000
# max        38.000000    1499.000000    1759.000000
# описание датасета internet:
# __________________________
#    Unnamed: 0      id  mb_used session_date  user_id  internet_id  \
# 0           0  1000_0   112.95   2018-11-25     1000            0
# 1           1  1000_1  1052.81   2018-09-07     1000            1
# 2           2  1000_2  1197.26   2018-06-25     1000            2
# 3           3  1000_3   550.27   2018-08-22     1000            3
# 4           4  1000_4   302.56   2018-09-24     1000            4
#
#   internet_month
# 0     2018-11-01
# 1     2018-09-01
# 2     2018-06-01
# 3     2018-08-01
# 4     2018-09-01
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      149396 non-null  int64
#  1   id              149396 non-null  object
#  2   mb_used         149396 non-null  float64
#  3   session_date    149396 non-null  datetime64[ns]
#  4   user_id         149396 non-null  uint16
#  5   internet_id     149396 non-null  uint16
#  6   internet_month  149396 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(1), uint16(2)
# memory usage: 6.3+ MB
# None
#           Unnamed: 0        mb_used        user_id    internet_id
# count  149396.000000  149396.000000  149396.000000  149396.000000
# mean    74697.500000     370.192426    1252.099842     205.811856
# std     43127.054745     278.300951     144.050823     157.267497
# min         0.000000       0.000000    1000.000000       0.000000
# 25%     37348.750000     138.187500    1130.000000      78.000000
# 50%     74697.500000     348.015000    1251.000000     172.000000
# 75%    112046.250000     559.552500    1380.000000     302.000000
# max    149395.000000    1724.830000    1499.000000     833.000000
# описание датасета messages:
# __________________________
#        id message_date  user_id  message_id message_month
# 0  1000_0   2018-06-27     1000           0    2018-06-01
# 1  1000_1   2018-10-08     1000           1    2018-10-01
# 2  1000_2   2018-08-04     1000           2    2018-08-01
# 3  1000_3   2018-06-16     1000           3    2018-06-01
# 4  1000_4   2018-12-05     1000           4    2018-12-01
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             123036 non-null  object
#  1   message_date   123036 non-null  datetime64[ns]
#  2   user_id        123036 non-null  uint16
#  3   message_id     123036 non-null  uint16
#  4   message_month  123036 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(1), uint16(2)
# memory usage: 3.3+ MB
# None
#              user_id     message_id
# count  123036.000000  123036.000000
# mean     1256.989410     267.595281
# std       143.523967     248.577464
# min      1000.000000       0.000000
# 25%      1134.000000      81.000000
# 50%      1271.000000     195.000000
# 75%      1381.000000     379.000000
# max      1499.000000    1462.000000
# описание датасета tariffs:
# __________________________
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      uint16
#  1   mb_per_month_included  2 non-null      uint16
#  2   minutes_included       2 non-null      uint16
#  3   rub_monthly_fee        2 non-null      uint16
#  4   rub_per_gb             2 non-null      uint16
#  5   rub_per_message        2 non-null      uint16
#  6   rub_per_minute         2 non-null      uint16
#  7   tariff_name            2 non-null      object
# dtypes: object(1), uint16(7)
# memory usage: 172.0+ bytes
# None
#        messages_included  mb_per_month_included  minutes_included  \
# count           2.000000               2.000000          2.000000
# mean          525.000000           23040.000000       1750.000000
# std           671.751442           10861.160159       1767.766953
# min            50.000000           15360.000000        500.000000
# 25%           287.500000           19200.000000       1125.000000
# 50%           525.000000           23040.000000       1750.000000
# 75%           762.500000           26880.000000       2375.000000
# max          1000.000000           30720.000000       3000.000000
#
#        rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute
# count         2.000000    2.000000         2.000000        2.000000
# mean       1250.000000  175.000000         2.000000        2.000000
# std         989.949494   35.355339         1.414214        1.414214
# min         550.000000  150.000000         1.000000        1.000000
# 25%         900.000000  162.500000         1.500000        1.500000
# 50%        1250.000000  175.000000         2.000000        2.000000
# 75%        1600.000000  187.500000         2.500000        2.500000
# max        1950.000000  200.000000         3.000000        3.000000
# описание датасета users:
# __________________________
#    user_id  age churn_date         city first_name  last_name   reg_date  \
# 0     1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3     1003   23        NaT       Москва      Белла   Белякова 2018-08-17
# 4     1004   68        NaT  Новокузнецк    Татьяна   Авдеенко 2018-05-14
#
#   tariff  reg_month
# 0  ultra 2018-05-01
# 1  smart 2018-11-01
# 2  smart 2018-06-01
# 3  ultra 2018-08-01
# 4  ultra 2018-05-01
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    uint16
#  1   age         500 non-null    uint8
#  2   churn_date  38 non-null     datetime64[ns]
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    datetime64[ns]
#  7   tariff      500 non-null    object
#  8   reg_month   500 non-null    datetime64[ns]
# dtypes: datetime64[ns](3), object(4), uint16(1), uint8(1)
# memory usage: 28.9+ KB
# None
#            user_id        age
# count   500.000000  500.00000
# mean   1249.500000   46.58800
# std     144.481833   16.66763
# min    1000.000000   18.00000
# 25%    1124.750000   32.00000
# 50%    1249.500000   46.00000
# 75%    1374.250000   62.00000
# max    1499.000000   75.00000

# %% [markdown]
# <a id='3'></a>
# # 3. Количество сделанных звонков и израсходованных минут разговора по месяцам

# %%
calls['dur_round'] = np.ceil(calls['duration'])

calls_grouped = calls.groupby(['user_id', 'call_month']).agg(
    {'call_id':'count',
     'dur_round': 'sum'    
}).rename(columns = {'call_id':'calls_count',
                    'dur_round':'minutes_spent'}).reset_index()

calls_grouped
# Out:
#       user_id call_month  calls_count  minutes_spent
# 0        1000 2018-05-01           22          159.0
# 1        1000 2018-06-01           43          172.0
# 2        1000 2018-07-01           47          340.0
# 3        1000 2018-08-01           52          408.0
# 4        1000 2018-09-01           58          466.0
# ...       ...        ...          ...            ...
# 3169     1498 2018-10-01           41          247.0
# 3170     1499 2018-09-01            9           70.0
# 3171     1499 2018-10-01           68          449.0
# 3172     1499 2018-11-01           74          612.0
# 3173     1499 2018-12-01           69          492.0
#
# [3174 rows x 4 columns]

# %% [markdown]
# <a id='4'></a>
# # 4. Количество отправленных сообщений по месяцам

# %%
messages_grouped = messages.groupby(['user_id', 'message_month']).agg(
    {'message_id':'count'    
}).rename(columns = {'message_id':'messages_count'}).reset_index()

messages_grouped
# Out:
#       user_id message_month  messages_count
# 0        1000    2018-05-01              22
# 1        1000    2018-06-01              60
# 2        1000    2018-07-01              75
# 3        1000    2018-08-01              81
# 4        1000    2018-09-01              57
# ...       ...           ...             ...
# 2712     1498    2018-10-01              42
# 2713     1499    2018-09-01              11
# 2714     1499    2018-10-01              48
# 2715     1499    2018-11-01              59
# 2716     1499    2018-12-01              66
#
# [2717 rows x 3 columns]

# %% [markdown]
# < id='5'></a>
# ## 5.Объем израсходованного интернет-трафика по месяцам

# %%
internet_grouped = internet.groupby(['user_id', 'internet_month']).agg(
    {'mb_used':'sum'    
}).reset_index()
internet_grouped['gb_used'] = internet_grouped['mb_used']/1024
internet_grouped['gb_used'] = np.ceil(internet_grouped['gb_used'])

internet_grouped
# Out:
#       user_id internet_month   mb_used  gb_used
# 0        1000     2018-05-01   2253.49      3.0
# 1        1000     2018-06-01  23233.77     23.0
# 2        1000     2018-07-01  14003.64     14.0
# 3        1000     2018-08-01  14055.93     14.0
# 4        1000     2018-09-01  14568.91     15.0
# ...       ...            ...       ...      ...
# 3198     1498     2018-10-01  20579.36     21.0
# 3199     1499     2018-09-01   1845.75      2.0
# 3200     1499     2018-10-01  17788.51     18.0
# 3201     1499     2018-11-01  17963.31     18.0
# 3202     1499     2018-12-01  13055.58     13.0
#
# [3203 rows x 4 columns]

# %% [markdown]
# <a id='6'></a>
# # 6. Расчет помесячной выручки с каждого пользователя по месяцам.

# %%
users_data = users.merge(calls_grouped, how = 'inner', left_on=['user_id'], right_on=['user_id'])
users_data = users_data.merge(messages_grouped, how = 'inner', left_on=['user_id','call_month'], right_on=['user_id','message_month'])
users_data = users_data.merge(internet_grouped, how = 'inner', left_on=['user_id','call_month'], right_on=['user_id','internet_month'])
users_data = users_data.merge(tariffs, how = 'inner', left_on=['tariff'], right_on=['tariff_name'])

users_data['calls_over_limit'] = users_data['minutes_spent']-users_data['minutes_included']
users_data.loc[users_data['calls_over_limit']<=0, ['calls_over_limit']] = 0
users_data['calls_over_limit'].unique()

users_data['internet_over_limit'] = np.ceil((users_data['mb_used']-users_data['mb_per_month_included'])/1024)
users_data.loc[users_data['internet_over_limit']<=0,['internet_over_limit']] = 0

users_data['messages_over_limit'] = users_data['messages_count']-users_data['messages_included']
users_data.loc[users_data['messages_over_limit']<0,['messages_over_limit']] = 0

users_data['revenue'] = users_data['calls_over_limit'] * users_data['rub_per_minute'] + users_data['messages_over_limit'] * users_data['rub_per_message'] + users_data['internet_over_limit'] * users_data['rub_per_gb']
        
users_data.loc[users_data['tariff'] == 'smart',['revenue']] +=550
users_data.loc[users_data['tariff'] == 'ultra',['revenue']] +=1950

display(users_data.isna().sum())

display(users_data.head())
users_data.revenue.describe()
# Out:
# user_id                     0
# age                         0
# churn_date               2528
# city                        0
# first_name                  0
# last_name                   0
# reg_date                    0
# tariff                      0
# reg_month                   0
# call_month                  0
# calls_count                 0
# minutes_spent               0
# message_month               0
# messages_count              0
# internet_month              0
# mb_used                     0
# gb_used                     0
# messages_included           0
# mb_per_month_included       0
# minutes_included            0
# rub_monthly_fee             0
# rub_per_gb                  0
# rub_per_message             0
# rub_per_minute              0
# tariff_name                 0
# calls_over_limit            0
# internet_over_limit         0
# messages_over_limit         0
# revenue                     0
# dtype: int64
#    user_id  age churn_date       city first_name  last_name   reg_date tariff  \
# 0     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
#
#    reg_month call_month  ...  minutes_included  rub_monthly_fee rub_per_gb  \
# 0 2018-05-01 2018-05-01  ...              3000             1950        150
# 1 2018-05-01 2018-06-01  ...              3000             1950        150
# 2 2018-05-01 2018-07-01  ...              3000             1950        150
# 3 2018-05-01 2018-08-01  ...              3000             1950        150
# 4 2018-05-01 2018-09-01  ...              3000             1950        150
#
#    rub_per_message rub_per_minute  tariff_name  calls_over_limit  \
# 0                1              1        ultra               0.0
# 1                1              1        ultra               0.0
# 2                1              1        ultra               0.0
# 3                1              1        ultra               0.0
# 4                1              1        ultra               0.0
#
#    internet_over_limit  messages_over_limit  revenue
# 0                  0.0                    0   1950.0
# 1                  0.0                    0   1950.0
# 2                  0.0                    0   1950.0
# 3                  0.0                    0   1950.0
# 4                  0.0                    0   1950.0
#
# [5 rows x 29 columns]
# count    2667.00000
# mean     1504.47994
# std       796.07941
# min       550.00000
# 25%       747.50000
# 50%      1550.00000
# 75%      1950.00000
# max      6770.00000
# Name: revenue, dtype: float64

# %% [markdown]
# <a id='7'></a>
# # 7. Анализ полученных данных

# %%
# Функция для вывода среднего, станд. отклонения, дисперсии + гистограммы
def stat_discr(data):
    s = {'Среднее набора данных' : round(data.mean(),2),
         'Медиана':round(data.median(),2),
         'Дисперсия набора данных' : round(np.var(data, ddof=1),2),
         'Стандартное отклонение': round(np.std(data, ddof=1),2)}
    display(s)
    data.hist(bins=30, alpha=0.7, figsize = (10,7))

# %%
diction = {'minutes_spent':'minutes_spent','mb_used':'mb_used','messages_count':'messages_count','revenue':'revenue'}
print('Данные от объёмах потребляемых услуг по пользователям тарифа SMART')
print('_____________________________________________________________________')
for key in diction:
    print(f'Анализ данных по {key}')
    stat_discr(users_data.loc[users_data['tariff'] == 'smart',[diction[key]]])
# Out:
# Данные от объёмах потребляемых услуг по пользователям тарифа SMART
# _____________________________________________________________________
# Анализ данных по minutes_spent
# {'Среднее набора данных': minutes_spent    421.03
#  dtype: float64,
#  'Медиана': minutes_spent    427.0
#  dtype: float64,
#  'Дисперсия набора данных': minutes_spent    35236.1
#  dtype: float64,
#  'Стандартное отклонение': minutes_spent    187.71
#  dtype: float64}
# Анализ данных по mb_used
# {'Среднее набора данных': mb_used    16245.24
#  dtype: float64,
#  'Медиана': mb_used    16461.94
#  dtype: float64,
#  'Дисперсия набора данных': mb_used    33558954.55
#  dtype: float64,
#  'Стандартное отклонение': mb_used    5793.01
#  dtype: float64}
# Анализ данных по messages_count
# {'Среднее набора данных': messages_count    38.77
#  dtype: float64,
#  'Медиана': messages_count    34.0
#  dtype: float64,
#  'Дисперсия набора данных': messages_count    718.8
#  dtype: float64,
#  'Стандартное отклонение': messages_count    26.81
#  dtype: float64}
# Анализ данных по revenue
# {'Среднее набора данных': revenue    1290.68
#  dtype: float64,
#  'Медиана': revenue    1012.0
#  dtype: float64,
#  'Дисперсия набора данных': revenue    677052.57
#  dtype: float64,
#  'Стандартное отклонение': revenue    822.83
#  dtype: float64}

# %% [markdown]
# ### Распределение потребляемых минут и интернет-трафика у пользоваталей тарифа "SMART" близко к нормальному. Распределение сообщений скошено вправо, среднее больше медианы

# %%
print('Данные от объёмах потребляемых услуг по пользователям тарифа ULTRA')
print('_____________________________________________________________________')
for key in diction:
    print(f'Анализ данных по {key}')
    stat_discr(users_data.loc[users_data['tariff'] == 'ultra',[diction[key]]])
# Out:
# Данные от объёмах потребляемых услуг по пользователям тарифа ULTRA
# _____________________________________________________________________
# Анализ данных по minutes_spent
# {'Среднее набора данных': minutes_spent    556.86
#  dtype: float64,
#  'Медиана': minutes_spent    537.5
#  dtype: float64,
#  'Дисперсия набора данных': minutes_spent    97258.41
#  dtype: float64,
#  'Стандартное отклонение': minutes_spent    311.86
#  dtype: float64}
# Анализ данных по mb_used
# {'Среднее набора данных': mb_used    19596.35
#  dtype: float64,
#  'Медиана': mb_used    19442.29
#  dtype: float64,
#  'Дисперсия набора данных': mb_used    92728051.39
#  dtype: float64,
#  'Стандартное отклонение': mb_used    9629.54
#  dtype: float64}
# Анализ данных по messages_count
# {'Среднее набора данных': messages_count    61.64
#  dtype: float64,
#  'Медиана': messages_count    53.0
#  dtype: float64,
#  'Дисперсия набора данных': messages_count    2008.55
#  dtype: float64,
#  'Стандартное отклонение': messages_count    44.82
#  dtype: float64}
# Анализ данных по revenue
# {'Среднее набора данных': revenue    2048.94
#  dtype: float64,
#  'Медиана': revenue    1950.0
#  dtype: float64,
#  'Дисперсия набора данных': revenue    110817.77
#  dtype: float64,
#  'Стандартное отклонение': revenue    332.89
#  dtype: float64}

# %% [markdown]
# ### Распределение потребляемых минут и интернет-трафика у пользоваталей тарифа "ULTRA" также близко к нормальному. Распределение сообщений скошено вправо

# %% [markdown]
# <a id='8'></a>
# # 8. Проверка гипотез

# %% [markdown]
# ### 8.1 Проверить предположение, что средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются.

# %%
alpha = .05 # критический уровень статистической значимости

results = st.ttest_ind(
    users_data.loc[users_data['tariff'] == 'ultra',['revenue']],
    users_data.loc[users_data['tariff'] == 'smart',['revenue']],
    equal_var = False) 

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу о равенстве выручки: средняя выручка пользователей тарфиов Смарт и Ультра отличаются")
else:
    print("Не получилось отвергнуть нулевую гипотезу о равенстве выручки: средняя выручка пользователей тарфиов Смарт и Ультра одинаковы")
# Out:
# p-значение: [1.61114231e-209]
# Отвергаем нулевую гипотезу: средняя выручка пользователей тарфиов Смарт и Ультра отличаются

# %% [markdown]
# ### 8.2 Проверить предположение, что средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.

# %%
users_data['tariff'].unique()
# Out:
# array(['ultra', 'smart'], dtype=object)

# %%
alpha = .05 # критический уровень статистической значимости

results = st.ttest_ind(
    users_data.loc[users_data['city'] == 'Москва',['revenue']],
    users_data.loc[~(users_data['city'] == 'Москва'),['revenue']],
    equal_var = False) 

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу о равенстве выручки: средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.")
else:
    print("Не получилось отвергнуть нулевую гипотезу о равенстве выручки: средняя выручка пользователей из Москвы НЕ отличается от выручки пользователей из других регионов.")
# Out:
# p-значение: [0.11142596]
# Не получилось отвергнуть нулевую гипотезу: средняя выручка пользователей из Москвы НЕ отличается от выручки пользователей из других регионов.

# %% [markdown]
# > Среднее "revenue" для SMART = 1290.68р./мес.
# * Звонки  421.03
# * интернет 16245.24
# * сообщенмя 38.77
#
# > Среднее "revenue" для ULTRA = 2048.94./мес.
# * Звонки 556,86
# * интернет 19596,35
# * сообщеня 61,64
